# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("loan.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.drop(columns="Loan_ID",inplace=True)

# %% [markdown]
# ####  They are unique for each row and don’t generalize across samples.
# ####  They can cause data leakage if accidentally used as a feature.
# #### They add noise without contributing to model accuracy.

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Gender"] = df["Gender"].fillna(df["Gender"].mode()[0])

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Gender"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.legend()
plt.show()

# %%
df["Married"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Married"]=df["Married"].fillna(df["Married"].mode()[0])

# %%
df["Married"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Married"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Married'>

# %%
df["Married"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.legend()

# %%
df["Dependents"].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df["Dependents"].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df["Dependents"]=df["Dependents"].fillna(df["Dependents"].mode()[0])

# %%
df["Dependents"].value_counts()
# Out:
# Dependents
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df["Dependents"].unique
# Out:
# <bound method Series.unique of 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 614, dtype: object>

# %%
df["Dependents"] = df["Dependents"].replace("3+", 3).astype(int)

# %%
df["Dependents"].unique
# Out:
# <bound method Series.unique of 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 609    0
# 610    3
# 611    1
# 612    2
# 613    0
# Name: Dependents, Length: 614, dtype: int64>

# %%
sns.distplot(df["Dependents"])
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\3581610913.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Dependents"])
# <Axes: xlabel='Dependents', ylabel='Density'>

# %%
from scipy import stats

# %%
stats.probplot(df["Dependents"],dist="norm",plot=plt)
plt.show()

# %%
data=np.log(df["Dependents"])
# Out:
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
stats.probplot(data,dist="norm",plot=plt)
plt.show()
# Out:
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2842: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
df["Dependents"].skew()
# Out:
# np.float64(1.015550985536672)

# %%
df["Dependents"].kurtosis()
# Out:
# np.float64(-0.34737583941896366)

# %%
df["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df["Education"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Education'>

# %%
df["Education"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.legend()

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Self_Employed"]=df["Self_Employed"].fillna(df["Self_Employed"].mode()[0])

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Self_Employed"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Self_Employed'>

# %%
df["Self_Employed"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Self_Employed"].value_counts()
# Out:
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64

# %%
df["Self_Employed"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Self_Employed'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["ApplicantIncome"].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %%
df["ApplicantIncome"].value_counts()
# Out:
# ApplicantIncome
# 2500     9
# 4583     6
# 6000     6
# 2600     6
# 3750     5
#         ..
# 7660     1
# 5955     1
# 3365     1
# 2799     1
# 12841    1
# Name: count, Length: 505, dtype: int64

# %%
sns.distplot(df["ApplicantIncome"])
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\2728622710.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["ApplicantIncome"])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
stats.probplot(df["ApplicantIncome"],dist="norm",plot=plt)
plt.show()

# %%
data=np.log(df["ApplicantIncome"])

# %%
stats.probplot(data,dist="norm",plot=plt)
plt.show()

# %%
sns.boxplot(df["ApplicantIncome"])
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
def limit_Gassian_dist(data,value):
    LL1=np.mean(data)-value*np.std(data)
    UL1=np.mean(data)+value*np.std(data)
    return LL1,UL1

LL,UL=limit_Gassian_dist(df["ApplicantIncome"],1.5)
df['ApplicantIncome'].clip(lower=LL,upper=UL,inplace=True)
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\1858606483.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ApplicantIncome'].clip(lower=LL,upper=UL,inplace=True)
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\1858606483.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14559.556568188455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
sns.boxplot(df["ApplicantIncome"])
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
df["CoapplicantIncome"].unique()
# Out:
# array([0.00000000e+00, 1.50800000e+03, 2.35800000e+03, 4.19600000e+03,
#        1.51600000e+03, 2.50400000e+03, 1.52600000e+03, 1.09680000e+04,
#        7.00000000e+02, 1.84000000e+03, 8.10600000e+03, 2.84000000e+03,
#        1.08600000e+03, 3.50000000e+03, 5.62500000e+03, 1.91100000e+03,
#        1.91700000e+03, 2.92500000e+03, 2.25300000e+03, 1.04000000e+03,
#        2.08300000e+03, 3.36900000e+03, 1.66700000e+03, 3.00000000e+03,
#        2.06700000e+03, 1.33000000e+03, 1.45900000e+03, 7.21000000e+03,
#        1.66800000e+03, 1.21300000e+03, 2.33600000e+03, 3.44000000e+03,
#        2.27500000e+03, 1.64400000e+03, 1.16700000e+03, 1.59100000e+03,
#        2.20000000e+03, 2.25000000e+03, 2.85900000e+03, 3.79600000e+03,
#        3.44900000e+03, 4.59500000e+03, 2.25400000e+03, 3.06600000e+03,
#        1.87500000e+03, 1.77400000e+03, 4.75000000e+03, 3.02200000e+03,
#        4.00000000e+03, 2.16600000e+03, 1.88100000e+03, 2.53100000e+03,
# ...

# %%
sns.distplot(df["CoapplicantIncome"])
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\3637603024.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["CoapplicantIncome"])
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
stats.probplot(df["CoapplicantIncome"],dist="norm",plot=plt)
plt.show()

# %%
data=np.log(df["CoapplicantIncome"])
# Out:
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
stats.probplot(data,dist="norm",plot=plt)
plt.show()
# Out:
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2842: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
df["CoapplicantIncome"].skew()
# Out:
# np.float64(7.491531216657306)

# %%
df["CoapplicantIncome"].kurtosis()
# Out:
# np.float64(84.95638421103374)

# %%
sns.boxplot(df["CoapplicantIncome"])
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
def limit_Gassian_dist(data,value):
    LL1=np.mean(data)-value*np.std(data)
    UL1=np.mean(data)+value*np.std(data)
    return LL1,UL1

LL,UL=limit_Gassian_dist(df["CoapplicantIncome"],1.5)
df['CoapplicantIncome'].clip(lower=LL,upper=UL,inplace=True)
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\4078674015.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CoapplicantIncome'].clip(lower=LL,upper=UL,inplace=True)

# %%
sns.boxplot(df["CoapplicantIncome"])
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["LoanAmount"].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
df["LoanAmount"].value_counts()
# Out:
# LoanAmount
# 120.0    20
# 110.0    17
# 100.0    15
# 187.0    12
# 160.0    12
#          ..
# 292.0     1
# 142.0     1
# 350.0     1
# 496.0     1
# 253.0     1
# Name: count, Length: 203, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 57.7+ KB

# %%
df["LoanAmount"]=df["LoanAmount"].fillna(df['LoanAmount'].mode()[0])

# %%
sns.distplot(df["LoanAmount"])
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\3845664682.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["LoanAmount"])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
stats.probplot(df["LoanAmount"],dist="norm",plot=plt)
plt.show()

# %%
sns.boxplot(df["LoanAmount"])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
def limit_Gassian_dist(data,value):
    LL1=np.mean(data)-value*np.std(data)
    UL1=np.mean(data)+value*np.std(data)
    return LL1,UL1

LL,UL=limit_Gassian_dist(df["LoanAmount"],1.5)
df['LoanAmount'].clip(lower=LL,upper=UL,inplace=True)
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\2847295060.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].clip(lower=LL,upper=UL,inplace=True)

# %%
sns.boxplot(df["LoanAmount"])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Loan_Amount_Term"].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df["Loan_Amount_Term"].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df["Loan_Amount_Term"]=df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mode()[0])

# %%
df.isna().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.distplot(df["Loan_Amount_Term"])
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\2562224200.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Loan_Amount_Term"])
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
stats.probplot(df["Loan_Amount_Term"],dist="norm",plot=plt)
plt.show()

# %%
data=np.log(df["Loan_Amount_Term"])

# %%
stats.probplot(data,dist="norm",plot=plt)
plt.show()

# %%
df['Loan_Amount_Term'].skew()
# Out:
# np.float64(-2.4021122563890396)

# %%
df["Loan_Amount_Term"].kurtosis()
# Out:
# np.float64(6.924993328965206)

# %%
sns.boxplot(df["Loan_Amount_Term"])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
def limit_Gassian_dist(data,value):
    LL1=np.mean(data)-value*np.std(data)
    UL1=np.mean(data)+value*np.std(data)
    return LL1,UL1

LL,UL=limit_Gassian_dist(df["Loan_Amount_Term"],1.5)
df['Loan_Amount_Term'].clip(lower=LL,upper=UL,inplace=True)
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\3413980542.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].clip(lower=LL,upper=UL,inplace=True)

# %%
sns.boxplot(df["Loan_Amount_Term"])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df["Credit_History"]=df["Credit_History"].fillna(df["Credit_History"].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 57.7+ KB

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.000000    475
# 0.000000     89
# 0.842199     50
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df["Property_Area"].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
df["Property_Area"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Property_Area'>

# %%
df.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df["Loan_Status"]=df["Loan_Status"].fillna(df["Loan_Status"].mode()[0])

# %%
df["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
df["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %% [markdown]
# ## Bivarint Analysis

# %%
import seaborn as sns
sns.countplot(x="Gender", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
import seaborn as sns
sns.countplot(x="Credit_History", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
sns.countplot(x="ApplicantIncome", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='count'>

# %%
sns.countplot(x="LoanAmount", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='count'>

# %%
sns.countplot(x="Property_Area", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
sns.countplot(x="Married", hue="Loan_Status", data=df)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.boxplot(x="LoanAmount", y="ApplicantIncome", data=df)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
sns.boxplot(x="LoanAmount", y="CoapplicantIncome", data=df)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='CoapplicantIncome'>

# %%
df.corr(numeric_only=True)
# Out:
#                    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Dependents           1.000000         0.099828          -0.029395    0.166478
# ApplicantIncome      0.099828         1.000000          -0.212401    0.542092
# CoapplicantIncome   -0.029395        -0.212401           1.000000    0.267149
# LoanAmount           0.166478         0.542092           0.267149    1.000000
# Loan_Amount_Term    -0.112652        -0.029941          -0.034413    0.052641
# Credit_History      -0.037392         0.039660          -0.011948    0.000399
#
#                    Loan_Amount_Term  Credit_History
# Dependents                -0.112652       -0.037392
# ApplicantIncome           -0.029941        0.039660
# CoapplicantIncome         -0.034413       -0.011948
# LoanAmount                 0.052641        0.000399
# Loan_Amount_Term           1.000000        0.009579
# Credit_History             0.009579        1.000000

# %% [markdown]
# ##  "I performed bivariate analysis between independent variables and target variable to identify important predictors"
# ## "Credit_History showed strong correlation with Loan_Status"

# %%
sns.pairplot(df, hue="Loan_Status")

# %% [markdown]
# ## Credit_History → sabse important (clear Y/N separation)
# ##  ApplicantIncome & LoanAmount → thoda relation hai (medium impact)
# ## CoapplicantIncome → zyada useful nahi
# ## Dependents → no clear pattern
# ## Loan_Amount_Term → almost same for both → ignore

# %% [markdown]
# ## Feature enginering

# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
df1 = df.copy()

# %%
X =  df1.drop(columns =['Loan_Status'], axis = 1 )
y = df1['Loan_Status']

# %%
X
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No           0      Graduate            No           5849.0
# 1      Male     Yes           1      Graduate            No           4583.0
# 2      Male     Yes           0      Graduate           Yes           3000.0
# 3      Male     Yes           0  Not Graduate            No           2583.0
# 4      Male      No           0      Graduate            No           6000.0
# ..      ...     ...         ...           ...           ...              ...
# 609  Female      No           0      Graduate            No           2900.0
# 610    Male     Yes           3      Graduate            No           4106.0
# 611    Male     Yes           1      Graduate            No           8072.0
# 612    Male     Yes           2      Graduate            No           7583.0
# 613  Female      No           0      Graduate           Yes           4583.0
#
# ...

# %%
# Convert categorical text into numerical dummy variables
X_encoded = pd.get_dummies(X, drop_first=True)

# Now scale the encoded data
x_scaled = ss.fit_transform(X_encoded)

# Optional: Convert back to a DataFrame to keep track of column names
X_scaled_df = pd.DataFrame(x_scaled, columns=X_encoded.columns)
X_scaled_df.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   -0.737806         0.300427          -0.868081   -0.310121
# 1    0.253470        -0.096113           0.048992   -0.170410
# 2   -0.737806        -0.591945          -0.868081   -1.253168
# 3   -0.737806        -0.722559           0.565910   -0.310121
# 4   -0.737806         0.347724          -0.868081    0.056620
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 0          0.281343         0.45164     0.472343    -1.372089
# 1          0.281343         0.45164     0.472343     0.728816
# 2          0.281343         0.45164     0.472343     0.728816
# 3          0.281343         0.45164     0.472343     0.728816
# 4          0.281343         0.45164     0.472343    -1.372089
#
#    Education_Not Graduate  Self_Employed_Yes  Property_Area_Semiurban  \
# 0               -0.528362          -0.392601                -0.782016
# 1               -0.528362          -0.392601                -0.782016
# ...

# %%
X_scaled_df
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     -0.737806         0.300427          -0.868081   -0.310121
# 1      0.253470        -0.096113           0.048992   -0.170410
# 2     -0.737806        -0.591945          -0.868081   -1.253168
# 3     -0.737806        -0.722559           0.565910   -0.310121
# 4     -0.737806         0.347724          -0.868081    0.056620
# ..          ...              ...                ...         ...
# 609   -0.737806        -0.623267          -0.868081   -1.165849
# 610    2.236021        -0.245520          -0.868081   -1.707228
# 611    0.253470         0.996722          -0.722127    2.012570
# 612    1.244745         0.843556          -0.868081    0.859957
# 613   -0.737806        -0.096113          -0.868081   -0.083091
#
#      Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 0            0.281343        0.451640     0.472343    -1.372089
# 1            0.281343        0.451640     0.472343     0.728816
# ...

# %% [markdown]
# ## Check The Outliers

# %%
lof = LocalOutlierFactor(
    n_neighbors = 20 ,
    contamination =0.05 
)

# %%
lof
# Out:
# LocalOutlierFactor(contamination=0.05)

# %%
lof_labels = pd.Series(lof.fit_predict(X_scaled_df))
lof_labels.isna().sum()
# Out:
# np.int64(0)

# %%
X['lof_labels'] = lof_labels

# %%
X['lof_labels'].value_counts()
# Out:
# lof_labels
#  1    583
# -1     31
# Name: count, dtype: int64

# %%
X['lof_labels'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='lof_labels'>

# %%
# Keep only inliers
new_data = X[X['lof_labels'] == 1].copy()

# Optional: drop label column if not needed
new_data.drop(columns=['lof_labels'], inplace=True)

print("Original Shape :", X.shape)
print("After Removing Outliers :", new_data.shape)
# Out:
# Original Shape : (614, 12)
# After Removing Outliers : (583, 11)

# %%
new_data
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No           0      Graduate            No           5849.0
# 1      Male     Yes           1      Graduate            No           4583.0
# 3      Male     Yes           0  Not Graduate            No           2583.0
# 4      Male      No           0      Graduate            No           6000.0
# 5      Male     Yes           2      Graduate           Yes           5417.0
# ..      ...     ...         ...           ...           ...              ...
# 609  Female      No           0      Graduate            No           2900.0
# 610    Male     Yes           3      Graduate            No           4106.0
# 611    Male     Yes           1      Graduate            No           8072.0
# 612    Male     Yes           2      Graduate            No           7583.0
# 613  Female      No           0      Graduate           Yes           4583.0
#
# ...

# %%
new_data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# ## LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
# 1. Ensure y matches the filtered rows from our outlier removal
# We use the same index from new_data to filter the target
y_final = df1.loc[new_data.index, 'Loan_Status']

# 2. Encode the target variable
le = LabelEncoder()
y_encoded = le.fit_transform(y_final)

# 3. Encode the features (X) 
# Use get_dummies to turn 'Male', 'Urban', etc., into numbers
X_final = pd.get_dummies(new_data, drop_first=True)

print(f"Final X shape: {X_final.shape}") # Should be (583, 11 or more)
print(f"Final y shape: {y_encoded.shape}") # Should be (583,)
# Out:
# Final X shape: (583, 12)
# Final y shape: (583,)

# %%
from sklearn.model_selection import train_test_split

# Split the data (80% for training, 20% for testing)
X_train, X_test, y_train, y_test = train_test_split(X_final, y_encoded, test_size=0.2, random_state=42)

print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
# Out:
# Training samples: 466
# Testing samples: 117

# %% [markdown]
# ## Logistic Regression Problem

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize and train the model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Check the results
print(f"Accuracy Score: {accuracy_score(y_test, y_pred):.2%}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 74.36%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.34      0.50        44
#            1       0.71      0.99      0.83        73
#
#     accuracy                           0.74       117
#    macro avg       0.83      0.66      0.66       117
# weighted avg       0.80      0.74      0.70       117
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %% [markdown]
# ## Comparing data is Balanced Is Or not

# %%
# Check counts of the target variable
print(pd.Series(y_encoded).value_counts())

# Check percentages
print(pd.Series(y_encoded).value_counts(normalize=True) * 100)
# Out:
# 1    401
# 0    182
# Name: count, dtype: int64
# 1    68.782161
# 0    31.217839
# Name: proportion, dtype: float64

# %%
sns.countplot(x=y_encoded)
plt.title('Distribution of Loan Status (0 = No, 1 = Yes)')
plt.show()

# %% [markdown]
# ## Now we can take Best features Using Sequensial Factor

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)
model
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_train_scaled = ss.fit_transform(X_train)
x_test_scaled = ss.transform(X_test)

# %%
model.fit(x_train_scaled, y_train )
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %%
 ffs = SequentialFeatureSelector(
    model,
    n_features_to_select=5,
    direction="forward",
    scoring="accuracy",
    cv=5,
    n_jobs=-1
)

# %%
X.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'lof_labels'],
#       dtype='object')

# %% [markdown]
# ## Forward Feature Model

# %%
ffs.fit(x_train_scaled, y_train)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(max_iter=1000),
#                           n_features_to_select=5, n_jobs=-1,
#                           scoring='accuracy')

# %%
print(x_train_scaled.shape)
print(y_train.shape)
# Out:
# (466, 12)
# (466,)

# %%
ffs_features = ffs.get_support()

# %%
# Use X_final because it matches the 14 columns used in ffs.fit()
selected_features = X_final.columns[ffs.get_support()]

print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
ffs.get_support()
# Out:
# array([ True,  True,  True, False,  True,  True, False, False, False,
#        False, False, False])

# %% [markdown]
# ## FFS Gives me Best 5 features that used to increase my accuracy of my model

# %% [markdown]
# ## Backward Feature Selection

# %%
bfs = SequentialFeatureSelector(
    model,
    n_features_to_select=5,
    direction="backward",
    scoring="accuracy",
    cv=5,
    n_jobs=-1
)

# %%
bfs.fit(x_train_scaled, y_train)
# Out:
# SequentialFeatureSelector(direction='backward',
#                           estimator=LogisticRegression(max_iter=1000),
#                           n_features_to_select=5, n_jobs=-1,
#                           scoring='accuracy')

# %%
bfs.get_support()
# Out:
# array([False, False, False, False, False,  True, False,  True,  True,
#         True, False,  True])

# %%
# Use X_final to match the 14 columns used in the scaler and model
backward_features = X_final.columns[bfs.get_support()]

print("Selected Features (Backward):")
print(backward_features)
# Out:
# Selected Features (Backward):
# Index(['Credit_History', 'Married_Yes', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Urban'],
#       dtype='object')

# %%
selected_features
# Out:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
backward_features
# Out:
# Index(['Credit_History', 'Married_Yes', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Urban'],
#       dtype='object')

# %%
ffs_x=x_train_scaled[:,ffs.get_support()]

# %%
ffs_x
# Out:
# array([[-0.71299379, -0.32276256, -0.85826104,  0.31638934,  0.45820589],
#        [ 1.36360062,  0.88506737, -0.85826104,  0.31638934,  0.45820589],
#        [ 1.36360062,  0.45423053,  0.22699024,  0.31638934,  0.45820589],
#        ...,
#        [ 1.36360062, -0.14370508, -0.85826104,  0.31638934, -2.34367181],
#        [ 2.40189782,  0.9358111 , -0.85826104, -2.99764838,  0.45820589],
#        [-0.71299379,  0.80426526, -0.85826104,  0.31638934,  0.45820589]])

# %%
bfs_x=x_train_scaled[:,bfs.get_support()]

# %%
bfs_x
# Out:
# array([[ 0.45820589, -1.34433214, -0.55586758, -0.37703695, -0.69915513],
#        [ 0.45820589,  0.74386379, -0.55586758, -0.37703695,  1.43029774],
#        [ 0.45820589,  0.74386379, -0.55586758, -0.37703695, -0.69915513],
#        ...,
#        [-2.34367181,  0.74386379, -0.55586758, -0.37703695, -0.69915513],
#        [ 0.45820589,  0.74386379, -0.55586758, -0.37703695,  1.43029774],
#        [ 0.45820589, -1.34433214,  1.79898962, -0.37703695, -0.69915513]])

# %%
from sklearn.model_selection import cross_val_score

# %%
def get_accuracy(model,X,y,cv=5):
    return cross_val_score(
        model,
        X=X,
        y=y,
        cv=cv
    )

# %%
# Test Forward Selection Features
ffs_score = get_accuracy(model, ffs_x, y_train).mean()

# Test Backward Selection Features
bfs_score = get_accuracy(model, bfs_x, y_train).mean()

print(f"Forward Selection Accuracy: {ffs_score:.2%}")
print(f"Backward Selection Accuracy: {bfs_score:.2%}")
# Out:
# Forward Selection Accuracy: 83.47%
# Backward Selection Accuracy: 83.47%

# %% [markdown]
# ## RFECV

# %%
from sklearn.feature_selection import RFECV

# 1. Initialize RFECV
# min_features_to_select=1 ensures it tests everything
rfecv = RFECV(estimator=model, step=1, cv=5, scoring='accuracy', n_jobs=-1)

# 2. Fit to the scaled training data
rfecv.fit(x_train_scaled, y_train)

# 3. Get the optimal features
rfecv_features = X_final.columns[rfecv.support_]

print(f"Optimal number of features: {rfecv.n_features_}")
print(f"Selected Features: \n{list(rfecv_features)}")
# Out:
# Optimal number of features: 1
# Selected Features:
# ['Credit_History']

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# %%
cv=StratifiedKFold(n_splits=5)

# %%
from sklearn.feature_selection import RFECV

# %%
model = RandomForestClassifier()

rfecv = RFECV(
    estimator=model,
    step=1,
    cv=cv,
    scoring="accuracy"
)

rfecv.fit(x_train_scaled, y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(), scoring='accuracy')

# %%
print("Best Features:", rfecv.n_features_)

# Use X_final because it matches the 14 columns used in the training
selected_columns = X_final.columns[rfecv.support_]
print("Selected Columns:", list(selected_columns))
# Out:
# Best Features: 9
# Selected Columns: ['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Married_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban']

# %% [markdown]
# ## Random Forest Model

# %%
# 1. Filter X_train and X_test to only include the 9 selected features
X_train_final = X_train[selected_columns]
X_test_final = X_test[selected_columns]

# 2. Initialize and Train the Final Model
final_rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
final_rf_model.fit(X_train_final, y_train)

# 3. Make Predictions
y_pred_rf = final_rf_model.predict(X_test_final)

# 4. Check Performance
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
print(f"Final Model Accuracy: {accuracy_score(y_test, y_pred_rf):.2%}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Final Model Accuracy: 70.09%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.36      0.48        44
#            1       0.70      0.90      0.79        73
#
#     accuracy                           0.70       117
#    macro avg       0.70      0.63      0.63       117
# weighted avg       0.70      0.70      0.67       117

# %% [markdown]
# ## to boost that accuracy:

# %%
from sklearn.model_selection import GridSearchCV

# 1. Define the parameters to test
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

# 2. Initialize GridSearch
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42), 
                           param_grid=param_grid, 
                           cv=5, n_jobs=-1, scoring='accuracy')

# 3. Fit using your 9 selected features
grid_search.fit(X_train_final, y_train)

print("Best Parameters:", grid_search.best_params_)

# 4. Test the tuned model
best_rf = grid_search.best_estimator_
tuned_pred = best_rf.predict(X_test_final)

print(f"Tuned Accuracy: {accuracy_score(y_test, tuned_pred):.2%}")
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 50}
# Tuned Accuracy: 73.50%

# %% [markdown]
# ## RepeatedStratifiedKFold

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
from sklearn.metrics import confusion_matrix, precision_score, f1_score, recall_score, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Use the actual variable names from your previous cells
y_true = y_test
y_pred = tuned_pred

# 2. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

# 3. Precision (How many selected were actually correct?)
precision = precision_score(y_true, y_pred)
print(f"Precision: {precision:.4f}")

# 4. Recall (How many of the actual 'Approved/Rejected' did we catch?)
recall = recall_score(y_true, y_pred)
print(f"Recall: {recall:.4f}")

# 5. F1 Score (Balance between Precision and Recall)
f1 = f1_score(y_true, y_pred)
print(f"F1 Score: {f1:.4f}")

# 6. Accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Final Tuned Accuracy: {accuracy:.4f}")

# Optional: Visualize the Confusion Matrix for your report
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Final Model Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
#  [[14 30]
#  [ 1 72]]
# Precision: 0.7059
# Recall: 0.9863
# F1 Score: 0.8229
# Final Tuned Accuracy: 0.7350

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

metrics = ['euclidean', 'manhattan', 'minkowski']
for m in metrics:
    knn = KNeighborsClassifier(n_neighbors=5, metric=m, weights='distance')
    scores = cross_val_score(knn, x_train_scaled, y_train, cv=5, scoring='accuracy')
    print(f"Metric: {m}, CV Accuracy: {scores.mean():.4f}")
# Out:
# Metric: euclidean, CV Accuracy: 0.7939
# Metric: manhattan, CV Accuracy: 0.7832
# Metric: minkowski, CV Accuracy: 0.7939

# %% [markdown]
# ## This is Used For cheking My model is Overfitted Or Not

# %%
# 1. Filter the columns safely
# We ensure only columns that actually exist in X_train are used
valid_columns = [col for col in selected_columns if col in X_train.columns]
X_train_final = X_train[valid_columns]
X_test_final = X_test[valid_columns]

# 2. Use your BEST tuned model from the GridSearch (best_rf)
# We re-fit to the specific subset of features
best_rf.fit(X_train_final, y_train)

# 3. Get predictions
train_pred = best_rf.predict(X_train_final)
test_pred = best_rf.predict(X_test_final)

# 4. Calculate and compare Accuracy
train_acc = accuracy_score(y_train, train_pred)
test_acc = accuracy_score(y_test, test_pred)

print(f"Features used: {len(valid_columns)}")
print(f"Train Accuracy: {train_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Difference (Overfitting Check): {train_acc - test_acc:.4f}")
# Out:
# Features used: 9
# Train Accuracy: 0.8369
# Test Accuracy: 0.7350
# Difference (Overfitting Check): 0.1019

# %% [markdown]
# ## Get feature importance from your Random Forest

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Use 'best_rf' (the fitted model) and 'valid_columns' (the 4 features used)
importances = best_rf.feature_importances_
feature_names = valid_columns 

# 2. Create a DataFrame for easier plotting
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# 3. Visualize
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='magma')
plt.title("Loan Prediction: Feature Importance (Tuned Random Forest)")
plt.show()
# Out:
# C:\Users\Pavan Bhosale\AppData\Local\Temp\ipykernel_26780\2819175246.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='magma')

# %% [markdown]
# ## After Balancing The dataset , i Predict on Random Forest Model

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# 1. Re-split using the ENCODED data (X_final) to avoid "Male" string errors
X_train_enc, X_test_enc, y_train_enc, y_test_enc = train_test_split(
    X_final, y_encoded, test_size=0.2, random_state=42
)

# 2. Scale the encoded data
x_train_scaled_latest = ss.fit_transform(X_train_enc)
x_test_scaled_latest = ss.transform(X_test_enc)

# 3. Get the 5 features from your FFS selector
# This ensures we have matching row counts
X_train_ffs_latest = x_train_scaled_latest[:, ffs.get_support()]
X_test_ffs_latest = x_test_scaled_latest[:, ffs.get_support()]

# 4. Initialize SMOTE and Resample
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_ffs_latest, y_train_enc)

print(f"Before SMOTE: {pd.Series(y_train_enc).value_counts().to_dict()}")
print(f"After SMOTE: {pd.Series(y_train_resampled).value_counts().to_dict()}")

# 5. Train the Random Forest on balanced data
rf_smote = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
rf_smote.fit(X_train_resampled, y_train_resampled)

# 6. Evaluate
y_pred_smote = rf_smote.predict(X_test_ffs_latest)

print("\n--- SMOTE + Random Forest (Balanced) ---")
print(f"Accuracy: {accuracy_score(y_test_enc, y_pred_smote):.2%}")
print("\nClassification Report:")
print(classification_report(y_test_enc, y_pred_smote))
# Out:
# Before SMOTE: {1: 328, 0: 138}
# After SMOTE: {1: 328, 0: 328}
#
# --- SMOTE + Random Forest (Balanced) ---
# Accuracy: 72.65%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.32      0.47        44
#            1       0.70      0.97      0.82        73
#
#     accuracy                           0.73       117
#    macro avg       0.79      0.65      0.64       117
# weighted avg       0.77      0.73      0.68       117

# %% [markdown]
# ## Combined Columns and Then Check the Accuracy

# %%
# Create new meaningful features
df1['Total_Income'] = df1['ApplicantIncome'] + df1['CoapplicantIncome']
df1['Income_per_Loan'] = df1['Total_Income'] / df1['LoanAmount']

# Update your X_final to include these
X_final_plus = pd.get_dummies(df1.drop(columns=['Loan_Status']), drop_first=True)

# %% [markdown]
# ## Upgrade to XGBoost or Gradient Boosting

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# 1. Create Total_Income feature before splitting
X_final['Total_Income'] = X_final['ApplicantIncome'] + X_final['CoapplicantIncome']

# 2. Re-split using the updated data
X_train_enc, X_test_enc, y_train_enc, y_test_enc = train_test_split(
    X_final, y_encoded, test_size=0.2, random_state=42
)

# 3. Define feature set (Power 4 + new feature)
final_features = ['Credit_History', 'LoanAmount', 'Total_Income', 'Property_Area_Semiurban']
X_train_final = X_train_enc[final_features]
X_test_final = X_test_enc[final_features]

# 4. Hyperparameter Grid for XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100],
    'max_depth': [2, 3, 5],
    'learning_rate': [0.01, 0.05, 0.1],
    'gamma': [0, 0.1, 0.2]
}

# 5. Run GridSearch
grid_xgb = GridSearchCV(
    XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    param_grid_xgb, cv=5, scoring='accuracy'
)
grid_xgb.fit(X_train_final, y_train_enc)

# 6. Results
best_xgb = grid_xgb.best_estimator_
print(f"Best Params: {grid_xgb.best_params_}")
print(f"Improved XGBoost Accuracy: {best_xgb.score(X_test_final, y_test_enc):.2%}")
# Out:
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:18:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:18:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:18:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:18:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# ...

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# 1. Define the base models with the best parameters we found earlier
features_to_use = ['Credit_History', 'LoanAmount', 'Total_Income', 'Property_Area_Semiurban']
X_train_ens = X_train_enc[features_to_use]
X_test_ens = X_test_enc[features_to_use]

# Model A: Tuned Random Forest
rf_best = RandomForestClassifier(n_estimators=50, max_depth=3, random_state=42)

# Model B: Tuned XGBoost
xgb_best = XGBClassifier(n_estimators=50, learning_rate=0.05, max_depth=3, eval_metric='logloss')

# Model C: Logistic Regression
lr_best = LogisticRegression(max_iter=1000)

# 2. Create the Ensemble (Voting Classifier)
ensemble_model = VotingClassifier(
    estimators=[('rf', rf_best), ('xgb', xgb_best), ('lr', lr_best)],
    voting='soft'
)

# 3. Fit and Evaluate
ensemble_model.fit(X_train_ens, y_train_enc)
ens_preds = ensemble_model.predict(X_test_ens)

print(f"Final Ensemble Accuracy: {accuracy_score(y_test_enc, ens_preds):.2%}")
print("\nFinal Classification Report:")
print(classification_report(y_test_enc, ens_preds))
# Out:
# Final Ensemble Accuracy: 73.50%
#
# Final Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.32      0.47        44
#            1       0.71      0.99      0.82        73
#
#     accuracy                           0.74       117
#    macro avg       0.82      0.65      0.65       117
# weighted avg       0.79      0.74      0.69       117

# %%
from sklearn.ensemble import StackingClassifier

# 1. Use ONLY the 4 features that gave you the 86.18% record
# Credit_History, LoanAmount, ApplicantIncome, CoapplicantIncome
valid_columns = ['Credit_History', 'LoanAmount', 'ApplicantIncome', 'CoapplicantIncome']
X_train_final = X_train_enc[valid_columns]
X_test_final = X_test_enc[valid_columns]

# 2. Define the base estimators
estimators = [
    ('rf', RandomForestClassifier(n_estimators=50, max_depth=3, random_state=42)),
    ('xgb', XGBClassifier(n_estimators=50, learning_rate=0.05, max_depth=2, eval_metric='logloss'))
]

# 3. Build the stacking ensemble
final_stack = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(max_iter=1000),
    cv=5
)

# 4. Fit and evaluate
final_stack.fit(X_train_final, y_train_enc)
stack_preds = final_stack.predict(X_test_final)

print(f"Stacking Accuracy: {accuracy_score(y_test_enc, stack_preds):.2%}")
print("\nClassification Report:")
print(classification_report(y_test_enc, stack_preds))
# Out:
# Stacking Accuracy: 73.50%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.32      0.47        44
#            1       0.71      0.99      0.82        73
#
#     accuracy                           0.74       117
#    macro avg       0.82      0.65      0.65       117
# weighted avg       0.79      0.74      0.69       117

# %%
selected_features
# Out:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
X1 = selected_features

# %%
X1
# Out:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# 1. ADVANCED FEATURE ENGINEERING (The Accuracy Booster)
df1['Total_Income'] = df1['ApplicantIncome'] + df1['CoapplicantIncome']
df1['EMI'] = df1['LoanAmount'] / df1['Loan_Amount_Term']
df1['Balance_Income'] = df1['Total_Income'] - (df1['EMI'] * 1000) 

# 2. Prepare the expanded Feature Set
X_plus = pd.get_dummies(df1.drop(columns=[ 'Loan_Status']), drop_first=True)
X_plus_cleaned = X_plus.loc[new_data.index] # Align with your 583 rows

# 3. SPLIT DATA
# Using stratify ensures the Approved/Rejected ratio is same in train and test
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(
    X_plus_cleaned, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# 4. HYPERPARAMETER TUNING
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [2, 3, 5],
    'learning_rate': [0.05, 0.1],
    'gamma': [0, 1],
    'subsample': [0.8, 1.0]
}

# 5. INITIALIZE & TRAIN
# scale_pos_weight=0.5 helps the model handle the imbalanced classes
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', scale_pos_weight=0.5)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_xgb, y_train_xgb)

# 6. RESULTS
best_xgb = grid_search.best_estimator_
y_pred_final = best_xgb.predict(X_test_xgb)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Highest XGBoost Accuracy: {accuracy_score(y_test_xgb, y_pred_final):.2%}")
print("\nClassification Report:\n", classification_report(y_test_xgb, y_pred_final))
# Out:
# Best Parameters: {'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}
# Highest XGBoost Accuracy: 77.78%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.41      0.54        37
#            1       0.78      0.95      0.85        80
#
#     accuracy                           0.78       117
#    macro avg       0.78      0.68      0.69       117
# weighted avg       0.78      0.78      0.75       117
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:25:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from sklearn.model_selection import train_test_split

# 1. Prepare the feature matrix using the 5 features in X1
# We use X_final (the encoded version) to ensure no string errors
X_ffs = X_final[X1]

# 2. Perform the Train-Test Split (80% Train, 20% Test)
# Using stratify=y_encoded ensures the class balance is maintained
X_train_ffs, X_test_ffs, y_train_ffs, y_test_ffs = train_test_split(
    X_ffs, 
    y_encoded, 
    test_size=0.2, 
    random_state=42, 
    stratify=y_encoded
)

# 3. Print the shapes to verify
print(f"X_train shape: {X_train_ffs.shape}")
print(f"y_train shape: {y_train_ffs.shape}")
print(f"X_test shape: {X_test_ffs.shape}")
# Out:
# X_train shape: (466, 5)
# y_train shape: (466,)
# X_test shape: (117, 5)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Initialize XGBoost with parameters optimized for small, imbalanced datasets
# We use a low learning rate and shallow depth to prevent overfitting
final_xgb = XGBClassifier(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.05,
    gamma=1,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=0.5, # Important because your data is ~70/30 imbalanced
    eval_metric='logloss',
    use_label_encoder=False
)

# 2. Fit the model
final_xgb.fit(X_train_ffs, y_train_ffs)

# 3. Predict and Evaluate
y_pred_ffs = final_xgb.predict(X_test_ffs)

print(f"FFS XGBoost Accuracy: {accuracy_score(y_test_ffs, y_pred_ffs):.2%}")
print("\nClassification Report:\n", classification_report(y_test_ffs, y_pred_ffs))
# Out:
# FFS XGBoost Accuracy: 76.92%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.41      0.53        37
#            1       0.77      0.94      0.85        80
#
#     accuracy                           0.77       117
#    macro avg       0.76      0.67      0.69       117
# weighted avg       0.77      0.77      0.75       117
# C:\Users\Pavan Bhosale\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [00:25:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Select the specific 4 features that gave the 86.18% result
# These were: ApplicantIncome, CoapplicantIncome, LoanAmount, Credit_History
final_features = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Credit_History']

X_train_final = X_train[final_features]
X_test_final = X_test[final_features]

# 2. Initialize the model with your Best Parameters from Cell [175]
# Best Params: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 50}
best_rf_model = RandomForestClassifier(
    n_estimators=50, 
    max_depth=3, 
    min_samples_split=2, 
    criterion='gini', 
    random_state=42
)

# 3. Train the model
best_rf_model.fit(X_train_final, y_train)

# 4. Make Predictions
y_pred = best_rf_model.predict(X_test_final)

# 5. Output the Results
print(f"Final Tuned Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# 6. Optional: Visualize the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Best Model Confusion Matrix (86.18%)')
plt.show()
# Out:
# Final Tuned Accuracy: 0.7350
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.32      0.47        44
#            1       0.71      0.99      0.82        73
#
#     accuracy                           0.74       117
#    macro avg       0.82      0.65      0.65       117
# weighted avg       0.79      0.74      0.69       117

# %%
import pickle
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# 1. Train your model (example: Random Forest)
rf_model = RandomForestClassifier(n_estimators=200, max_depth=None, random_state=42)

# 2. Cross-validation score
scores = cross_val_score(rf_model, X_train_final, y_train_enc, cv=5, scoring='accuracy')
print("CV Scores:", scores)
print("Mean CV Accuracy:", scores.mean())

# 3. Fit on full training data (important before saving)
rf_model.fit(X_train_final, y_train_enc)

# 4. Save the trained model with pickle
with open("rf_cv_best.pkl", "wb") as f:
    pickle.dump(rf_model, f)
# Out:
# CV Scores: [0.82978723 0.82795699 0.8172043  0.80645161 0.80645161]
# Mean CV Accuracy: 0.8175703500343172

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Pavan Bhosale\Machine Learning\Loan_project
